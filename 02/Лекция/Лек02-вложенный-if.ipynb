# %% [markdown]
# # Вложенный условный оператор
# ## `AND`, `OR`, `NOT`
#
# **Основы программирования на Python**
#
# Сегодня:
# - составные логические условия;
# - `and`, `or`, `not`;
# - приоритет логических операций;
# - вложенный `if`;
# - выбор между вложенностью и составным условием.

# %% [markdown]
# # Зачем нужны составные условия?
#
# Одного сравнения часто недостаточно.
#
# Например:
#
# > Число должно быть **положительным И чётным**.
#
# Нужно проверить сразу два утверждения:
#
# ```python
# x > 0
# x % 2 == 0
# ```
#
# Как объединить их в одно условие?

# %% [markdown]
# # Логические операции
#
# В Python используются три основные логические операции:
#
# | Python | Читаем | Идея |
# |---|---|---|
# | `and` | И | должны выполняться оба условия |
# | `or` | ИЛИ | достаточно хотя бы одного |
# | `not` | НЕ | меняет истину на ложь и наоборот |
#
# Результат логического выражения — `True` или `False`.

# %% [markdown]
# # `and` — логическое И
#
# ```python
# A and B
# ```
#
# Истинно **только тогда, когда истинны оба условия**.
#
# | A | B | `A and B` |
# |---|---|---|
# | False | False | False |
# | False | True | False |
# | True | False | False |
# | True | True | True |
#
# Пример:
#
# ```python
# x > 0 and x % 2 == 0
# ```
#
# Число одновременно положительное **и** чётное.

# %% [markdown]
# # `and`: принадлежность промежутку
#
# Нужно проверить:
#
# > число `x` принадлежит отрезку `[10; 20]`
#
# Через `and`:
#
# ```python
# x >= 10 and x <= 20
# ```
#
# В Python можно записать короче:
#
# ```python
# 10 <= x <= 20
# ```
#
# Обе записи выражают одну идею: должны выполняться **обе границы**.

# %% [markdown]
# # `or` — логическое ИЛИ
#
# ```python
# A or B
# ```
#
# Истинно, если **хотя бы одно** условие истинно.
#
# | A | B | `A or B` |
# |---|---|---|
# | False | False | False |
# | False | True | True |
# | True | False | True |
# | True | True | True |
#
# Пример:
#
# ```python
# x % 3 == 0 or x % 5 == 0
# ```
#
# Число делится на 3 **или** на 5.

# %% [markdown]
# # Важная особенность `or`
#
# Фраза:
#
# > делится на 3 или на 5
#
# обычно означает **хотя бы одно из условий**.
#
# Число `15` тоже подходит:
#
# ```python
# 15 % 3 == 0   # True
# 15 % 5 == 0   # True
# ```
#
# Поэтому:
#
# ```python
# True or True
# ```
#
# даёт `True`.

# %% [markdown]
# # `not` — логическое НЕ
#
# ```python
# not A
# ```
#
# меняет логическое значение на противоположное.
#
# | A | `not A` |
# |---|---|
# | False | True |
# | True | False |
#
# Например:
#
# ```python
# not (x > 0)
# ```
#
# означает:
#
# > неверно, что `x` положительно
#
# то есть:
#
# ```python
# x <= 0
# ```

# %% [markdown]
# # Несколько операций в одном условии
#
# Можно объединять несколько логических операций:
#
# ```python
# x > 0 and (x % 2 == 0 or x % 3 == 0)
# ```
#
# Читаем:
#
# > `x` положительно **И** при этом делится на 2 **ИЛИ** на 3.
#
# Скобки помогают явно показать смысл условия.

# %% [markdown]
# # Приоритет операций
#
# Порядок выполнения:
#
# 1. сравнения: `<`, `>`, `<=`, `>=`, `==`, `!=`;
# 2. `not`;
# 3. `and`;
# 4. `or`.
#
# Поэтому:
#
# ```python
# A or B and C
# ```
#
# равносильно:
#
# ```python
# A or (B and C)
# ```
#
# ### Правило
# Если условие сложно читать — **ставьте скобки**.

# %% [markdown]
# # Перевод условия задачи в код
#
# Условие:
#
# > Число положительное и двузначное или равно нулю.
#
# Разбиваем на части:
#
# ```text
# A: x > 0
# B: 10 <= x <= 99
# C: x == 0
# ```
#
# Логическая схема:
#
# ```text
# (A AND B) OR C
# ```
#
# Python:
#
# ```python
# (x > 0 and 10 <= x <= 99) or x == 0
# ```

# %% [markdown]
# # Вложенный условный оператор
#
# Внутри одного `if` может находиться другой `if`.
#
# ```python
# if условие_1:
#     if условие_2:
#         действие
# ```
#
# Второе условие проверяется **только тогда**, когда первое истинно.
#
# Это позволяет строить последовательность проверок.

# %% [markdown]
# # Пример вложенного `if`
#
# Сначала проверяем логин.
#
# Только если логин правильный — проверяем пароль.
#
# ```python
# if login == "admin":
#     if password == "1234":
#         print("Доступ разрешён")
#     else:
#         print("Неверный пароль")
# else:
#     print("Неизвестный пользователь")
# ```
#
# Вторая проверка имеет смысл только после успешной первой.

# %% [markdown]
# # Отступы определяют структуру
#
# ```python
# if A:
#     if B:
#         print("1")
#     else:
#         print("2")
# else:
#     print("3")
# ```
#
# `else` относится к `if`, находящемуся **на том же уровне отступа**.
#
# В Python отступ — не оформление, а часть синтаксиса программы.

# %% [markdown]
# # Вложенный `if` или `and`?
#
# ### Вложенный вариант
#
# ```python
# if x > 0:
#     if x % 2 == 0:
#         print("Подходит")
# ```
#
# ### Составное условие
#
# ```python
# if x > 0 and x % 2 == 0:
#     print("Подходит")
# ```
#
# Если требуется просто проверить несколько признаков одновременно, составное условие обычно короче.
#
# Если после первой проверки появляются **разные сценарии**, вложенный `if` часто удобнее.

# %% [markdown]
# # Отрицание составного условия
#
# ```python
# not (x > 0 and x < 10)
# ```
#
# означает:
#
# > неверно, что `x` находится внутри `(0; 10)`.
#
# Эквивалентно:
#
# ```python
# x <= 0 or x >= 10
# ```
#
# Законы де Моргана:
#
# ```text
# NOT (A AND B) = (NOT A) OR (NOT B)
# NOT (A OR B)  = (NOT A) AND (NOT B)
# ```

# %% [markdown]
# # Частые ошибки
#
# ❌
# ```python
# if x == 3 or 5:
# ```
#
# ✅
# ```python
# if x == 3 or x == 5:
# ```
#
# ---
#
# ❌
# ```python
# if x > 10 and < 20:
# ```
#
# ✅
# ```python
# if x > 10 and x < 20:
# ```
#
# или
#
# ```python
# if 10 < x < 20:
# ```

# %% [markdown]
# # Что нужно уметь
#
# После теории:
#
# - составлять условия с `and`, `or`, `not`;
# - читать сложные логические выражения;
# - правильно расставлять скобки;
# - переводить условие задачи в Python;
# - использовать вложенные `if`;
# - понимать структуру по отступам;
# - выбирать между составным условием и вложенностью.
#
# # Теперь — задачи

# %% [markdown]
# # Практика
#
# ## 20 задач без решений
#
# Рекомендуемый порядок работы:
#
# 1. выделить простые условия;
# 2. определить связи `И`, `ИЛИ`, `НЕ`;
# 3. расставить скобки;
# 4. решить, нужен ли вложенный `if`;
# 5. только после этого писать программу.

# %% [markdown]
# # Задача 1
# ## Положительное и чётное
#
# Вводится целое число. Выведите `YES`, если оно **положительное и чётное**. Иначе выведите `NO`.

# %% [markdown]
# # Задача 2
# ## Делимость
#
# Вводится целое число. Выведите `YES`, если оно делится **на 3 или на 5**. Иначе выведите `NO`.

# %% [markdown]
# # Задача 3
# ## Принадлежность отрезку
#
# Вводится целое число `x`. Определите, принадлежит ли оно отрезку **[−10; 25]**.

# %% [markdown]
# # Задача 4
# ## Вне промежутка
#
# Вводится целое число `x`. Выведите `YES`, если оно **не принадлежит** интервалу `(5; 20)`.

# %% [markdown]
# # Задача 5
# ## Последняя цифра
#
# Вводится натуральное число. Выведите `YES`, если его последняя цифра равна **2, 5 или 8**.

# %% [markdown]
# # Задача 6
# ## Два числа
#
# Вводятся два целых числа. Выведите `YES`, если **хотя бы одно** из них отрицательное.

# %% [markdown]
# # Задача 7
# ## Одинаковая чётность
#
# Вводятся два целых числа. Выведите `YES`, если они **оба чётные или оба нечётные**.

# %% [markdown]
# # Задача 8
# ## Двузначное число
#
# Вводится целое число. Выведите `YES`, если оно является **двузначным** и делится **на 3 или на 5**.

# %% [markdown]
# # Задача 9
# ## Наибольшее или равные
#
# Вводятся три целых числа `a`, `b`, `c`. Выведите `YES`, если `a` больше `b` и `c` **или все три числа равны**.

# %% [markdown]
# # Задача 10
# ## Координатные четверти
#
# Вводятся координаты точки `x`, `y`. Выведите `YES`, если точка находится **во II или IV координатной четверти**. Точки на осях не подходят.

# %% [markdown]
# # Задача 11
# ## Времена года
#
# Вводится номер месяца. Выведите `YES`, если он соответствует **летнему или зимнему** месяцу. Иначе выведите `NO`.

# %% [markdown]
# # Задача 12
# ## Ровно одно отрицательное
#
# Вводятся три целых числа. Определите, является ли **ровно одно** из них отрицательным. Циклы и коллекции использовать нельзя.

# %% [markdown]
# # Задача 13
# ## Знак и чётность
#
# Вводится целое число. Если оно положительное, определите, **чётное оно или нечётное**. Если отрицательное — выведите `Отрицательное`. Если равно нулю — `Ноль`. Используйте вложенный условный оператор.

# %% [markdown]
# # Задача 14
# ## Логин и пароль
#
# Вводятся логин и пароль. Правильный логин — `student`, пароль — `python`. Сначала проверьте логин. Только если он верен, проверяйте пароль. Выведите подходящее сообщение для каждого случая.

# %% [markdown]
# # Задача 15
# ## Скидка
#
# Вводятся возраст покупателя и стоимость покупки. Если покупателю меньше 18 лет — скидка недоступна. Иначе при покупке от 5000 рублей скидка составляет 10%, а при меньшей сумме — 5%. Выведите размер скидки.

# %% [markdown]
# # Задача 16
# ## Проверка данных
#
# Вводятся год и номер месяца. Если год неположительный — данные некорректны. Иначе проверьте, находится ли номер месяца в диапазоне от 1 до 12. Используйте вложенный `if`.

# %% [markdown]
# # Задача 17
# ## Положение точки
#
# Вводятся координаты `x`, `y`. Выведите одно из сообщений: `Начало координат`, `Ось X`, `Ось Y`, `I четверть`, `II четверть`, `III четверть`, `IV четверть`. Продумайте порядок проверок.

# %% [markdown]
# # Задача 18
# ## Треугольник
#
# Вводятся длины сторон `a`, `b`, `c`. Сначала определите, **существует ли треугольник**. Если существует, определите его тип: равносторонний, равнобедренный или разносторонний.

# %% [markdown]
# # Задача 19
# ## Корректная дата
#
# Вводятся день и номер месяца невисокосного года. Проверьте корректность даты. В феврале 28 дней; в апреле, июне, сентябре и ноябре — 30; в остальных месяцах — 31. Циклы и коллекции использовать нельзя.

# %% [markdown]
# # Задача 20
# ## Система допуска
#
# Вводятся возраст, наличие пропуска (`Да`/`Нет`) и количество нарушений. До 14 лет доступ запрещён. От 14 до 17 лет нужен пропуск и 0 нарушений. С 18 лет доступ разрешён, если есть пропуск **или** количество нарушений равно 0. Выведите `Доступ разрешён` или `Доступ запрещён`.

# %% [markdown]
# # **Основы программирования на Python (сетевой) — семинар**
# ## **0. Вложенный условный оператор. `OR`, `AND`, `NOT`**

# %% [markdown]
# ## Часть 1. `and`, `or`, `not`

# %% [markdown]
# **Задача 1.**
# Вводится целое число. Выведите `YES`, если число одновременно положительное и чётное. Иначе выведите `NO`.

# %% [markdown]
# **Задача 2.**
# Вводится целое число. Выведите `YES`, если оно делится на 3 или на 7. Иначе выведите `NO`.

# %% [markdown]
# **Задача 3.**
# Вводится целое число. Определите, принадлежит ли оно отрезку `[15; 40]`.

# %% [markdown]
# **Задача 4.**
# Вводится целое число. Выведите `YES`, если число **не принадлежит** интервалу `(10; 100)`.

# %% [markdown]
# **Задача 5.**
# Вводится натуральное число. Выведите `YES`, если последняя цифра числа равна 2, 5 или 8.

# %% [markdown]
# **Задача 6.**
# Вводятся два целых числа. Выведите `YES`, если хотя бы одно из них отрицательное.

# %% [markdown]
# **Задача 7.**
# Вводятся два целых числа. Выведите `YES`, если оба числа чётные или оба числа нечётные.

# %% [markdown]
# ## Часть 2. Составные условия

# %% [markdown]
# **Задача 8.**
# Вводится целое число. Выведите `YES`, если число является двузначным и делится на 3 или на 5.

# %% [markdown]
# **Задача 9.**
# Вводятся три целых числа. Выведите `YES`, если первое число является наибольшим среди трёх или все три числа равны.

# %% [markdown]
# **Задача 10.**
# Вводятся координаты точки `x` и `y`. Определите, находится ли точка во II или IV координатной четверти. Точки на осях не подходят.

# %% [markdown]
# **Задача 11.**
# Вводится номер месяца. Выведите `YES`, если номер соответствует летнему или зимнему месяцу (`12`, `1`, `2`, `6`, `7`, `8`). Иначе выведите `NO`.

# %% [markdown]
# **Задача 12.**
# Вводятся три целых числа. Выведите `YES`, если ровно первое и второе числа положительны, а третье отрицательно, **или** первое отрицательно, а второе и третье положительны.

# %% [markdown]
# ## Часть 3. Вложенный условный оператор

# %% [markdown]
# **Задача 13.**
# Вводится целое число.
#
# - Если число положительное, определите, чётное оно или нечётное.
# - Если число отрицательное, выведите `Отрицательное`.
# - Если число равно нулю, выведите `Ноль`.
#
# Для положительного числа выведите `Положительное чётное` или `Положительное нечётное`.

# %% [markdown]
# **Задача 14.**
# Вводятся логин и пароль.
#
# Правильный логин: `student`.
# Правильный пароль: `python`.
#
# Сначала проверьте логин. Если он неверен, выведите `Неверный логин`. Если логин верен, проверьте пароль и выведите `Доступ разрешён` или `Неверный пароль`.

# %% [markdown]
# **Задача 15.**
# Вводятся три числа. Сначала сравните первое и второе.
#
# - Если первое больше второго, выведите большее из первого и третьего.
# - Иначе выведите меньшее из второго и третьего.
#
# Решите задачу с использованием вложенного условного оператора.

# %% [markdown]
# **Задача 16.**
# Вводятся возраст человека и целое число — стоимость покупки.
#
# Если возраст меньше 18 лет, вывести `Скидка недоступна`.
# Если возраст не меньше 18 лет:
# - при стоимости покупки не меньше 5000 вывести `Скидка 10%`;
# - иначе вывести `Скидка 5%`.

# %% [markdown]
# **Задача 17.**
# Вводится год и номер месяца.
#
# Если год положительный, проверьте корректность номера месяца (`1..12`).
# Если месяц корректен, выведите `Корректные данные`, иначе — `Некорректный месяц`.
# Если год неположительный, выведите `Некорректный год`.
#
# Используйте вложенный `if`.

# %% [markdown]
# ## Часть 4. Читаем код и ищем ошибки

# %% [markdown]
# **Задача 18.**
# Что выведет программа для каждого значения `x`: `-4`, `3`, `8`?
#
# ```python
# if x > 0:
#     if x % 2 == 0:
#         print("A")
#     else:
#         print("B")
# else:
#     print("C")
# ```
#
# Ответ объясните.

# %% [markdown]
# **Задача 19.**
# Исправьте условие:
#
# ```python
# x = int(input())
#
# if x == 1 or 3 or 5:
#     print("YES")
# ```
#
# Программа должна выводить `YES` только для чисел `1`, `3` и `5`.

# %% [markdown]
# **Задача 20.**
# Исправьте условие:
#
# ```python
# x = int(input())
#
# if x >= 10 and <= 99:
#     print("Двузначное")
# ```
#
# После исправления программа должна корректно работать и для отрицательных двузначных чисел.

# %% [markdown]
# **Задача 21.**
# Расставьте скобки так, чтобы условие означало:
#
# > `a` положительно, и при этом хотя бы одно из чисел `b` и `c` чётное.
#
# ```python
# a > 0 and b % 2 == 0 or c % 2 == 0
# ```

# %% [markdown]
# ## Часть 5. Задачи повышенной сложности

# %% [markdown]
# **Задача 22.**
# Вводятся три целых числа. Определите, существует ли среди них **ровно одно** отрицательное число.
#
# Циклы и списки использовать нельзя.

# %% [markdown]
# **Задача 23.**
# Вводятся три целых числа. Определите, есть ли среди них два числа одного знака и одно число другого знака. Ноль не считать ни положительным, ни отрицательным.
#
# Циклы и списки использовать нельзя.

# %% [markdown]
# **Задача 24.**
# Вводятся координаты точки `x`, `y`.
#
# Определите положение точки и выведите одно из сообщений:
# - `Начало координат`;
# - `Ось X`;
# - `Ось Y`;
# - `I четверть`;
# - `II четверть`;
# - `III четверть`;
# - `IV четверть`.
#
# Продумайте порядок проверок.

# %% [markdown]
# **Задача 25.**
# Вводятся три длины сторон `a`, `b`, `c`.
#
# Сначала определите, может ли существовать треугольник с такими сторонами. Если может, дополнительно определите его тип:
# - `Равносторонний`;
# - `Равнобедренный`;
# - `Разносторонний`.
#
# Если треугольник не существует, выведите `Треугольник не существует`.
#
# Используйте составные условия и вложенный условный оператор.

# %% [markdown]
# **Задача 26.**
# Вводятся день и номер месяца невисокосного года.
#
# Проверьте корректность даты. Для февраля допустимы дни `1..28`, для апреля, июня, сентября и ноября — `1..30`, для остальных месяцев — `1..31`.
#
# Выведите `Корректная дата` или `Некорректная дата`.
#
# Циклы, списки и множества использовать нельзя.

# %% [markdown]
# ## Часть 6. Итоговая задача

# %% [markdown]
# **Задача 27. Система допуска**
#
# Вводятся:
# 1. возраст пользователя;
# 2. строка `Да` или `Нет` — есть ли пропуск;
# 3. целое число — количество нарушений.
#
# Правила:
# - пользователи младше 14 лет не допускаются;
# - для пользователей от 14 до 17 лет включительно нужен пропуск и должно быть 0 нарушений;
# - пользователи от 18 лет допускаются, если у них есть пропуск **или** количество нарушений равно 0.
#
# Выведите `Доступ разрешён` или `Доступ запрещён`.
#
# Сначала составьте логическую схему решения. Затем реализуйте программу. Попробуйте написать:
# 1. вариант со вложенными `if`;
# 2. вариант с составным логическим условием.

# %% [markdown]
# # Семинар: основы Python и условный оператор — часть 1
#
# Практическое занятие по материалам лекции.
# Задачи идут от коротких упражнений на базовый синтаксис к задачам с несколькими ветками `if / elif / else`.
#
# **Важно:** в этом семинаре не используются новые темы за пределами лекции.
# Не используйте циклы, списки, функции, `and`, `or`, `not` и вложенные `if`.

# %% [markdown]
# ## Часть 1. Вывод, типы данных и переменные
#
# Первые задачи нужны, чтобы разогреться и вспомнить базовые конструкции Python.

# %% [markdown]
# ### Задача 1. Афиша занятия
# Создайте переменные `course`, `lesson` и `room`. Выведите одной командой `print()` сообщение вида:
#
# `Python | Занятие 2 | Аудитория 305`

# %%
# Ваш код

# %% [markdown]
# ### Задача 2. Параметры спутника
# Даны высота орбиты `height = 550` км и скорость `speed = 7.6` км/с.
# Выведите оба значения с понятными подписями.

# %%
# Ваш код

# %% [markdown]
# ### Задача 3. Смена значения
# Стоимость билета хранится в переменной `price` и равна 1200. Затем цена увеличилась на 300.
# Измените значение переменной и выведите новую цену.

# %%
# Ваш код

# %% [markdown]
# ### Задача 4. Баллы студента
# За три работы студент получил 17, 23 и 14 баллов.
# Сохраните результаты в трёх переменных и выведите сумму.

# %%
# Ваш код

# %% [markdown]
# ## Часть 2. Арифметика, деление и остаток

# %% [markdown]
# ### Задача 5. Поездка
# Автомобиль проехал 315 км за 4.5 часа.
# Вычислите среднюю скорость.

# %%
# Ваш код

# %% [markdown]
# ### Задача 6. Пицца на компанию
# Есть 37 кусочков пиццы и 8 студентов.
# Выведите:
# - сколько целых кусочков получит каждый;
# - сколько кусочков останется.

# %%
# Ваш код

# %% [markdown]
# ### Задача 7. Электронные часы
# С начала суток прошло `n` минут. Пользователь вводит `n`.
# Выведите количество полных часов и оставшихся минут.

# %%
# Ваш код

# %% [markdown]
# ### Задача 8. Номер билета
# Пользователь вводит положительное целое число.
# Выведите его последнюю цифру.

# %%
# Ваш код

# %% [markdown]
# ### Задача 9. Предпоследняя цифра
# Пользователь вводит положительное целое число, содержащее хотя бы две цифры.
# Выведите предпоследнюю цифру.

# %%
# Ваш код

# %% [markdown]
# ### Задача 10. Трёхзначный код
# Пользователь вводит трёхзначное положительное число.
# Выведите его цифры по одной, начиная с первой.

# %%
# Ваш код

# %% [markdown]
# ## Часть 3. `input()` и преобразование типов

# %% [markdown]
# ### Задача 11. Год выпуска
# Пользователь вводит год поступления в университет.
# Выведите предполагаемый год окончания четырёхлетней программы.

# %%
# Ваш код

# %% [markdown]
# ### Задача 12. Заказ кофе
# Пользователь вводит цену одного напитка и количество напитков.
# Выведите общую стоимость заказа.

# %%
# Ваш код

# %% [markdown]
# ### Задача 13. Делим счёт
# Пользователь вводит общую сумму счёта и количество человек.
# Выведите сумму на одного человека.

# %%
# Ваш код

# %% [markdown]
# ### Задача 14. Температура
# Пользователь вводит температуру в градусах Цельсия.
# Переведите её в градусы Фаренгейта по формуле:
#
# `F = C * 9 / 5 + 32`

# %%
# Ваш код

# %% [markdown]
# ## Часть 4. Строки

# %% [markdown]
# ### Задача 15. Университетский бейдж
# Пользователь вводит имя и название направления.
# Выведите строку вида:
#
# `Анна — Прикладная математика`

# %%
# Ваш код

# %% [markdown]
# ### Задача 16. Заголовок
# Пользователь вводит название проекта.
# Выведите его между двумя одинаковыми строками из символов `=`.

# %%
# Ваш код

# %% [markdown]
# ### Задача 17. Эхо
# Пользователь вводит короткое слово.
# Выведите это слово три раза подряд, разделив копии пробелами.

# %%
# Ваш код

# %% [markdown]
# ## Часть 6. Первый `if`

# %% [markdown]
# ### Задача 18. Мороз
# Пользователь вводит температуру.
# Если температура ниже нуля, выведите `Осторожно: мороз`.
#
# Если условие не выполнено, программа ничего дополнительно не выводит.

# %%
# Ваш код

# %% [markdown]
# ### Задача 19. Бонус
# Пользователь вводит количество набранных баллов.
# Если баллов не меньше 90, прибавьте к результату 5 бонусных баллов.
# После проверки выведите итоговый результат.

# %%
# Ваш код

# %% [markdown]
# ## Часть 7. `if / else`

# %% [markdown]
# ### Задача 20. Чётное или нечётное
# Пользователь вводит целое число.
# Выведите `Чётное` или `Нечётное`.

# %%
# Ваш код

# %% [markdown]
# ### Задача 21. Экзамен
# Пользователь вводит результат экзамена.
# Если результат не меньше 60, выведите `Зачтено`, иначе — `Не зачтено`.

# %%
# Ваш код

# %% [markdown]
# ### Задача 22. Лифт
# Пользователь вводит массу груза. Максимальная допустимая масса — 400 кг.
# Выведите `Можно ехать`, если ограничение не превышено, иначе — `Перегруз`.

# %%
# Ваш код

# %% [markdown]
# ### Задача 23. Ближайшая станция
# Пользователь вводит расстояние до станции A и расстояние до станции B.
# Гарантируется, что расстояния различны.
# Выведите `A`, если станция A ближе, иначе `B`.

# %%
# Ваш код

# %% [markdown]
# ## Часть 8. `if / elif / else`

# %% [markdown]
# ### Задача 24. Знак числа
# Пользователь вводит число.
# Выведите `Положительное`, `Отрицательное` или `Ноль`.

# %%
# Ваш код

# %% [markdown]
# ### Задача 25. Место в рейтинге
# Пользователь вводит место участника:
# - `1` → `Золото`;
# - `2` → `Серебро`;
# - `3` → `Бронза`;
# - любое другое значение → `Без медали`.

# %%
# Ваш код

# %% [markdown]
# ### Задача 26. Светофор
# Пользователь вводит цвет сигнала: `red`, `yellow` или `green`.
#
# Выведите соответственно:
# - `Стой`;
# - `Приготовься`;
# - `Иди`.
#
# Для любого другого значения выведите `Неизвестный сигнал`.

# %%
# Ваш код

# %% [markdown]
# ### Задача 27. Оценка за курс
# Пользователь вводит балл от 0 до 100.
#
# Выведите:
# - от 90 — `Отлично`;
# - от 75 — `Хорошо`;
# - от 60 — `Зачёт`;
# - меньше 60 — `Незачёт`.
#
# Расположите проверки так, чтобы не приходилось задавать верхнюю границу каждого диапазона.

# %%
# Ваш код

# %% [markdown]
# ### Задача 28. Тариф доставки
# Пользователь вводит массу посылки.
#
# Стоимость доставки:
# - до 1 кг включительно — 300 рублей;
# - до 5 кг включительно — 500 рублей;
# - более 5 кг — 800 рублей.
#
# Выведите стоимость доставки.

# %%
# Ваш код

# %% [markdown]
# ### Задача 29. Этаж
# В учебном корпусе:
# - этажи 1–2 — `Администрация`;
# - этажи 3–5 — `Учебные аудитории`;
# - этажи 6 и выше — `Лаборатории`.
#
# Пользователь вводит номер этажа.
# Постройте решение последовательными `if / elif / else`, не используя логические операции.

# %%
# Ваш код

# %% [markdown]
# ### Задача 30. Уровень заряда
# Пользователь вводит заряд аккумулятора в процентах.
#
# Выведите:
# - от 80 — `Высокий`;
# - от 30 — `Средний`;
# - от 10 — `Низкий`;
# - меньше 10 — `Критический`.

# %%
# Ваш код

# %% [markdown]
# ### Задача 31. Стоимость хранения
# Пользователь вводит объём данных в ГБ.
#
# Тариф:
# - до 10 ГБ включительно — бесплатно;
# - до 100 ГБ включительно — 2 рубля за каждый ГБ сверх 10;
# - больше 100 ГБ — 180 рублей плюс 1.5 рубля за каждый ГБ сверх 100.
#
# Выведите стоимость хранения.

# %%
# Ваш код

# %% [markdown]
# ### Задача 32. Время ответа сервера
# Пользователь вводит время ответа сервера в миллисекундах.
#
# Классификация:
# - до 100 мс включительно — `Отлично`;
# - до 300 мс включительно — `Нормально`;
# - до 500 мс включительно — `Медленно`;
# - больше 500 мс — `Очень медленно`.

# %%
# Ваш код

# %% [markdown]
# ### Задача 33. Три разных числа
# Пользователь вводит три **различных** числа `a`, `b`, `c`.
# Выведите наибольшее из них.
#
# Не используйте `max()` и не используйте вложенные `if`.

# %%
# Ваш код

# %% [markdown]
# ### Задача 34. Среднее из трёх
# Пользователь вводит три **различных** числа.
# Выведите число, которое находится между двумя другими по величине.
#
# Не используйте сортировку, `min()`, `max()`, логические операции и вложенные `if`.
#
# Подсказка: подумайте, можно ли последовательно исключать крайние случаи с помощью `if / elif / else`.

# %%
# Ваш код
